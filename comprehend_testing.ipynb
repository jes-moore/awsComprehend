# %%
# General
from tqdm import tqdm_notebook as tqdm
import json
import re
import pandas as pd
import pickle

# %%
def process_txt(x):
    '''
    Text preprocessing pipeline that returns
    a processed string
    '''
    regex = re.compile(r'[►*/-@.?!&~,":#$;\'()=+|0-9]')  # Remove Characters
    x = regex.sub("", x)  # Run Regex
    x = x.replace('  ', ' ')  # Replace Double Spaces
    x = x.replace('-', ' ')  # Replace Hyphens
    return x

def process_and_load_thinktank_json(filename):
    # Load Data
    with open(filename, 'r') as f:
        articles_df = pd.DataFrame(json.load(f)['articles_data'])

#     DEBUG
#     articles_df = articles_df[0:50]

    # Clean Text For Use in API
    articles_df.title = articles_df.title.apply(process_txt)
    articles_df.text = articles_df.text.apply(process_txt)
    articles_df['titleText'] = articles_df.title + articles_df.text

    # Remove Empty Strings
    articles_df = articles_df[articles_df.titleText.apply(lambda x: len(x)) != 0]

    # Max Character Length for AWS Comprehend = 5000 Characters
    articles_df.titleText = articles_df.titleText.apply(lambda x: x[0:4000])

    # Drop Unused Columns
    articles_df.drop(['url', 'text', 'title'],axis=1,inplace=True)
    
    return articles_df

# %%
def batchProcessComprehend(input_list, batch_size=25):
    def callEntityApi(text_list):
        return client.batch_detect_entities(
            TextList=text_list, LanguageCode='en')

    def callKeyphraseApi(text_list):
        return client.batch_detect_key_phrases(
            TextList=text_list, LanguageCode='en')
    
    def callSentimentAPI(text_list):
        return client.batch_detect_sentiment(
            TextList=text_list, LanguageCode='en')

    # Connect To Session
    session = boto3.Session(profile_name='damocles')
    comprehend = session.client('comprehend', region_name='eu-west-2')
    
    # Get Batches
    batches = [input_list[i:i + batch_size] for 
               i in range(0, len(input_list), batch_size)]
    
    # Init
    entity_li = []
    keyphrase_li = []
    sentiment_li = []
    sentiment_score_li = []


    for batch in tqdm(batches):
        # Extract Entities
        entity_response = callEntityApi(batch)
        entity_li += [
            r['Entities'] for r in entity_response['ResultList']]

        # Extract Keyphrase
        keyphrase_response = callKeyphraseApi(batch)
        keyphrase_li += [
            r['KeyPhrases'] for r in keyphrase_response['ResultList']]
        
        # Extract Sentiment
        sentiment_response = callSentimentAPI(batch)
        sentiment_li += [
            r['Sentiment'] for r in sentiment_response['ResultList']]
        sentiment_score_li += [
            r['SentimentScore'] for r in sentiment_response['ResultList']]
        
    return entity_li, keyphrase_li, sentiment_li, sentiment_score_li

# %%
# Load Data
filename = 'data/think_tanks_thinktank_articles.json'
articles_df = process_and_load_thinktank_json(filename)

# Attach Entites, KeyPhrases, Sentiment
articles_df['entities'],\
articles_df['keyphrases'],\
articles_df['sentiment'],\
articles_df['sentiment_score']=\
    batchProcessComprehend(articles_df.titleText.values.tolist())

# Save To Pickle
with open('ent_sent_keyphrase.pickle', 'wb') as handle:
    pickle.dump(articles_df, handle)
# Out:
# HBox(children=(IntProgress(value=0, max=116), HTML(value='')))

# %%
def extract_node(x):
    date = str(x.date)
    keyphrases = [item['Text'] for item in x.keyphrases]
    entities = [item['Text'] for item in x.entities]
    topics = x.topics
    return (date, keyphrases, entities, topics)

articles_df.apply(extract_node, axis=1).values[1]

# %%
articles_df.apply(extract_node, axis=1).values[1]
# Out:
# ('May\xa024,\xa02019',
#  ['implementation',
#   'awareness',
#   'the UN Sustainable Development Goals',
#   'Sri Lanka\n\n[',
#   'This article',
#   'Southern Voice',
#   'July',
#   'The article',
#   'a component',
#   'the success',
#   'the Sustainable Goals SDGs',
#   'Sri Lanka',
#   'a nation',
#   'wide education and awareness',
#   'campaign',
#   'the goals',
#   'The author',
#   'a high level authority',
#   'the responsibility]',
#   'Three years',
#   'Sri Lanka',
#   'the\xa0 Sustainable Development Goals SDGs',
#   'all but one member state',
#   'These goals',
#   'the Agenda',
#   'the overarching aim',
#   'poverty',
#   'social economic and environmental issues',
#   'nature',
#   'the Agenda Sri Lanka',
#   'several steps',
#   'its realization',
#   'This July Sri Lanka',
#   'the\xa0first voluntary national review',
#   'the High Level Political Forum',
#   'Its purpose',
#   'the extent',
#   'the nation',
#   'progress',
#   'the SDGs Several Sri Lankan stakeholders',
#   'proactive steps',
#   'the SDGs',
#   'the National Planning Department',
#   'the Department',
#   'Census and Statistics',
#   'various ministries',
#   'the Ministry',
#   'Health',
#   'the Parliamentary Select Committee',
#   'Their efforts',
#   'a critical aspect',
#   'implementation',
#   'the need',
#   'a nation',
#   'wide education and awareness',
#   'campaign',
#   'the goals',
#   'a component',
#   'a successful implementation\nSDG implementation',
#   'Sri Lanka',
#   'February the\xa0Sustainable Development Division',
#   'Sri Lanka',
#   '’s Ministry',
#   'Sustainable Development',
#   'Wildlife MSDW',
#   'Its mandate',
#   'the lead role',
#   'SDG implementation monitoring and evaluation',
#   'the formulation',
#   'sustainable development policies guidelines',
#   'tools',
#   'fact',
#   'several government agencies',
#   'different activities',
#   'SDG implementation',
#   'the extent',
#   'these agencies',
#   'actions',
#   'instance',
#   'the National Planning Department NPD',
#   'the Ministry',
#   'Finance',
#   'SDGs',
#   'the targets',
#   'the national development framework',
#   'parallel',
#   'the Department',
#   'Census and Statistics DCS',
#   'SDG indicators',
#   'data\nStrategic plans',
#   'a road map',
#   'the implementation',
#   'the SDG agenda',
#   'food security and nutrition',
#   'the SDG priority goals',
#   'Sri Lanka',
#   'The Ministry',
#   'Agriculture and Health',
#   'the School Health and Nutrition Division Ministry',
#   'Education',
#   'the nutrition status',
#   'women and children',
#   'Sri Lanka',
#   'agriculture productivity',
#   'activities',
#   'behavioural change policy programmes',
#   'guidance',
#   'nutrition policy formation planning and execution',
#   'programmes\nChallenges',
#   'decentralized implementation',
#   'SDGs',
#   'Sri Lanka',
#   'The flagship report',
#   'Sri Lanka State',
#   'the Economy',
#   'the Institute',
#   'Policy Studies IPS',
#   'Sri Lanka',
#   'discussions',
#   'stakeholders',
#   'the SDGs',
#   'certain ministries',
#   'local government officials',
#   'the private sector communities',
#   'even the media',
#   'my view',
#   'the prevalence',
#   'inadequate knowledge',
#   'the overall Agenda',
#   'multiple agencies',
#   'distinct components',
#   'SDG implementation',
#   'a result',
#   'the central importance',
#   'awareness',
#   'all stakeholders',
#   'a lack',
#   'awareness',
#   'the active role',
#   'this transformative agenda',
#   'the same patrons',
#   'the\xa0complexities',
#   'the importance',
#   'the relevance',
#   'the SDGs',
#   'certain instances knowledge and understanding',
#   'the SDGs',
#   'a few selected government officials'],
#  ['UN',
#   'Sri Lanka',
#   'Southern Voice',
#   'July',
#   'Sri Lanka',
#   'Three years ago',
#   'Sri Lanka',
#   'Sustainable Development Goals SDGs',
#   'one member',
#   'Sri Lanka',
#   'This July',
#   'Sri Lanka',
#   'first',
#   'Sri Lankan',
#   'National Planning Department',
#   'Department of Census and Statistics',
#   'Ministry of Health',
#   'Parliamentary Select Committee',
#   'SDG',
#   'Sri Lanka',
#   'February',
#   'Sustainable Development Division',
#   'Sri Lanka',
#   'Ministry of Sustainable Development and Wildlife MSDW',
#   'SDG',
#   'SDG',
#   'National Planning Department NPD',
#   'Ministry of Finance',
#   'SDGs',
#   'Department of Census and Statistics DCS',
#   'SDG',
#   'SDG',
#   'one',
#   'SDG',
#   'Sri Lanka',
#   'Ministry of Agriculture and Health',
#   'School Health and Nutrition Division Ministry of Education',
#   'Sri Lanka',
#   'SDGs',
#   'Sri Lanka',
#   'Sri Lanka State',
#   'Institute of Policy Studies IPS',
#   'Sri Lanka',
#   'SDG'],
#  ['Collaboration',
#   'Communications and impact',
#   'monitoring and evaluation',
#   'Policy Influence',
#   'SDGs',
#   'South Asia'])

# %%
articles_df
# Out:
#         category            date  \
# 0     Case study    May 24, 2019
# 1     Case study    May 24, 2019
# 2     Case study    May 24, 2019
# 3     Case study    May 24, 2019
# 4     Case study    May 24, 2019
# 5     Case study    May 24, 2019
# 6     Case study    May 24, 2019
# 7        Opinion    May 15, 2019
# 8       Research    May 13, 2019
# 9        Opinion  April 25, 2019
# 10       Opinion  April 18, 2019
# 11      Research  April 18, 2019
# 12    Case study    May 24, 2019
# 13    Case study    May 24, 2019
# 14    Case study    May 24, 2019
# 15    Case study    May 24, 2019
# 16    Case study    May 24, 2019
# 17    Case study    May 24, 2019
# 18    Case study    May 24, 2019
# 19       Opinion    May 15, 2019
# 20      Research    May 13, 2019
# 21       Opinion  April 25, 2019
# 22       Opinion  April 18, 2019
# 23      Research  April 18, 2019
# 24    Case study    May 24, 2019
# 25    Case study    May 24, 2019
# 26    Case study    May 24, 2019
# 27    Case study    May 24, 2019
# 28    Case study    May 24, 2019
# 29    Case study    May 24, 2019
# ...          ...             ...
# 2850     Opinion  March 31, 2017
# 2851     Opinion  March 30, 2017
# 2852     Opinion  March 16, 2017
# 2853     Opinion  March 13, 2017
# 2854     Opinion  March 10, 2017
# 2855     Opinion   March 6, 2017
# 2856     Opinion    May 11, 2017
# 2857     Opinion    May 10, 2017
# 2858     Opinion     May 9, 2017
# 2859     Opinion   April 5, 2017
# 2860  Case study   April 5, 2017
# 2861     Opinion   April 2, 2017
# 2862     Opinion  March 31, 2017
# 2863     Opinion  March 30, 2017
# 2864     Opinion  March 16, 2017
# 2865     Opinion  March 13, 2017
# 2866     Opinion  March 10, 2017
# 2867     Opinion   March 6, 2017
# 2868     Opinion    May 11, 2017
# 2869     Opinion    May 10, 2017
# 2870     Opinion     May 9, 2017
# 2871     Opinion   April 5, 2017
# 2872  Case study   April 5, 2017
# 2873     Opinion   April 2, 2017
# 2874     Opinion  March 31, 2017
# 2875     Opinion  March 30, 2017
# 2876     Opinion  March 16, 2017
# 2877     Opinion  March 13, 2017
# 2878     Opinion  March 10, 2017
# 2879     Opinion   March 6, 2017
#
#                                                  topics  \
# 0     [Collaboration, Communications and impact, pol...
# 1     [Collaboration, Communications and impact, mon...
# 2     [Africa, Communications and impact, Functions,...
# 3     [Collaboration, Communications and impact, Inf...
# 4     [Collaboration, Communications and impact, Pol...
# 5     [Collaboration, Communications and impact, Pol...
# 6     [Capacity Development, Collaboration, Communic...
# 7     [Communication, Communications and impact, Pol...
# 8     [Education, Research, The RSA, Think tanks and...
# 9     [ACBF, policy design, policy implementation, U...
# 10    [Communication, Evidence based Policy, Policy ...
# 11    [Communication, Communications and impact, gen...
# 12    [Collaboration, Communications and impact, pol...
# 13    [Collaboration, Communications and impact, mon...
# 14    [Africa, Communications and impact, Functions,...
# 15    [Collaboration, Communications and impact, Inf...
# 16    [Collaboration, Communications and impact, Pol...
# 17    [Collaboration, Communications and impact, Pol...
# 18    [Capacity Development, Collaboration, Communic...
# 19    [Communication, Communications and impact, Pol...
# 20    [Education, Research, The RSA, Think tanks and...
# 21    [ACBF, policy design, policy implementation, U...
# 22    [Communication, Evidence based Policy, Policy ...
# 23    [Communication, Communications and impact, gen...
# 24    [Collaboration, Communications and impact, pol...
# 25    [Collaboration, Communications and impact, mon...
# 26    [Africa, Communications and impact, Functions,...
# 27    [Collaboration, Communications and impact, Inf...
# 28    [Collaboration, Communications and impact, Pol...
# 29    [Collaboration, Communications and impact, Pol...
# ...                                                 ...
# 2850  [Advocacy, Communications and impact, Ranking,...
# 2851                        [Understanding think tanks]
# 2852  [Domestic Funding, Funding, Funding and suppor...
# 2853                        [Understanding think tanks]
# 2854  [Communication, Communications, Communications...
# 2855  [Communications and impact, Influence, Learnin...
# 2856  [Communication, Communications, Communications...
# 2857  [Governance and Management, How to attract and...
# 2858  [Daniel W. Drezner, Ideas Marketplace, Public ...
# 2859               [Funding and supporting think tanks]
# 2860  [Annual Report, Communication, Communications ...
# 2861  [Funding, Funding and supporting think tanks, ...
# 2862  [Advocacy, Communications and impact, Ranking,...
# 2863                        [Understanding think tanks]
# 2864  [Domestic Funding, Funding, Funding and suppor...
# 2865                        [Understanding think tanks]
# 2866  [Communication, Communications, Communications...
# 2867  [Communications and impact, Influence, Learnin...
# 2868  [Communication, Communications, Communications...
# 2869  [Governance and Management, How to attract and...
# 2870  [Daniel W. Drezner, Ideas Marketplace, Public ...
# 2871               [Funding and supporting think tanks]
# 2872  [Annual Report, Communication, Communications ...
# 2873  [Funding, Funding and supporting think tanks, ...
# 2874  [Advocacy, Communications and impact, Ranking,...
# 2875                        [Understanding think tanks]
# 2876  [Domestic Funding, Funding, Funding and suppor...
# 2877                        [Understanding think tanks]
# 2878  [Communication, Communications, Communications...
# 2879  [Communications and impact, Influence, Learnin...
#
#                                               titleText  \
# 0     Health concerns in India in the SDGs era\n\nTh...
# 1     From planning to implementation raising awaren...
# 2     Think tanks contributing towards the health re...
# 3     Improved health and nutrition contributing to ...
# 4     Achieving the Sustainable Development Goals in...
# 5     Process matters when it comes to implementing ...
# 6     Is a focus on happiness enough to help a count...
# 7     How deeply should think tanks engage with publ...
# 8     The great dilemmas that universities face in t...
# 9     Bridging the policy design and implementation ...
# 10    Experts from organisations with acronyms\n\n[T...
# 11    The Open Think Tank Directory a journey\n\n\n\...
# 12    Health concerns in India in the SDGs era\n\nTh...
# 13    From planning to implementation raising awaren...
# 14    Think tanks contributing towards the health re...
# 15    Improved health and nutrition contributing to ...
# 16    Achieving the Sustainable Development Goals in...
# 17    Process matters when it comes to implementing ...
# 18    Is a focus on happiness enough to help a count...
# 19    How deeply should think tanks engage with publ...
# 20    The great dilemmas that universities face in t...
# 21    Bridging the policy design and implementation ...
# 22    Experts from organisations with acronyms\n\n[T...
# 23    The Open Think Tank Directory a journey\n\n\n\...
# 24    Health concerns in India in the SDGs era\n\nTh...
# 25    From planning to implementation raising awaren...
# 26    Think tanks contributing towards the health re...
# 27    Improved health and nutrition contributing to ...
# 28    Achieving the Sustainable Development Goals in...
# 29    Process matters when it comes to implementing ...
# ...                                                 ...
# 2850  Rating and ranking institutions to drive chang...
# 2851  Looking forward reflections from OTT’s regiona...
# 2852  Mobilising domestic funding for think tanks in...
# 2853  What are think tanks doing in South East Asia ...
# 2854  Monitoring your communications try this\n\n[Th...
# 2855  Reflections on monitoring evaluation and learn...
# 2856  Six things to know about making an effective f...
# 2857  A new face for HR practices in think tanks\n\n...
# 2858  The Ideas Industry by Daniel W Drezner part \n...
# 2859  Kivu International’s work with developing worl...
# 2860  Producing the OTT annual report\n\nA few years...
# 2861  Can think tanks ruled by the wealthy be really...
# 2862  Rating and ranking institutions to drive chang...
# 2863  Looking forward reflections from OTT’s regiona...
# 2864  Mobilising domestic funding for think tanks in...
# 2865  What are think tanks doing in South East Asia ...
# 2866  Monitoring your communications try this\n\n[Th...
# 2867  Reflections on monitoring evaluation and learn...
# 2868  Six things to know about making an effective f...
# 2869  A new face for HR practices in think tanks\n\n...
# 2870  The Ideas Industry by Daniel W Drezner part \n...
# 2871  Kivu International’s work with developing worl...
# 2872  Producing the OTT annual report\n\nA few years...
# 2873  Can think tanks ruled by the wealthy be really...
# 2874  Rating and ranking institutions to drive chang...
# 2875  Looking forward reflections from OTT’s regiona...
# 2876  Mobilising domestic funding for think tanks in...
# 2877  What are think tanks doing in South East Asia ...
# 2878  Monitoring your communications try this\n\n[Th...
# 2879  Reflections on monitoring evaluation and learn...
#
#                                                entities  \
# 0     [{'Score': 0.9796985387802124, 'Type': 'LOCATI...
# 1     [{'Score': 0.48153752088546753, 'Type': 'ORGAN...
# 2     [{'Score': 0.9832321405410767, 'Type': 'DATE',...
# 3     [{'Score': 0.8823003172874451, 'Type': 'LOCATI...
# 4     [{'Score': 0.9901058077812195, 'Type': 'LOCATI...
# 5     [{'Score': 0.8568176031112671, 'Type': 'TITLE'...
# 6     [{'Score': 0.5432640910148621, 'Type': 'LOCATI...
# 7     [{'Score': 0.8117936849594116, 'Type': 'ORGANI...
# 8     [{'Score': 0.7044923901557922, 'Type': 'DATE',...
# 9     [{'Score': 0.6703212857246399, 'Type': 'LOCATI...
# 10    [{'Score': 0.9837647676467896, 'Type': 'PERSON...
# 11    [{'Score': 0.6322913765907288, 'Type': 'QUANTI...
# 12    [{'Score': 0.9796985387802124, 'Type': 'LOCATI...
# 13    [{'Score': 0.48153752088546753, 'Type': 'ORGAN...
# 14    [{'Score': 0.9832321405410767, 'Type': 'DATE',...
# 15    [{'Score': 0.8823003172874451, 'Type': 'LOCATI...
# 16    [{'Score': 0.9901058077812195, 'Type': 'LOCATI...
# 17    [{'Score': 0.8568176031112671, 'Type': 'TITLE'...
# 18    [{'Score': 0.5432640910148621, 'Type': 'LOCATI...
# 19    [{'Score': 0.8117936849594116, 'Type': 'ORGANI...
# 20    [{'Score': 0.7044923901557922, 'Type': 'DATE',...
# 21    [{'Score': 0.6703212857246399, 'Type': 'LOCATI...
# 22    [{'Score': 0.9837647676467896, 'Type': 'PERSON...
# 23    [{'Score': 0.6322913765907288, 'Type': 'QUANTI...
# 24    [{'Score': 0.9796985387802124, 'Type': 'LOCATI...
# 25    [{'Score': 0.48153752088546753, 'Type': 'ORGAN...
# 26    [{'Score': 0.9832321405410767, 'Type': 'DATE',...
# 27    [{'Score': 0.8823003172874451, 'Type': 'LOCATI...
# 28    [{'Score': 0.9901058077812195, 'Type': 'LOCATI...
# 29    [{'Score': 0.8568176031112671, 'Type': 'TITLE'...
# ...                                                 ...
# 2850  [{'Score': 0.6757462620735168, 'Type': 'QUANTI...
# 2851  [{'Score': 0.7196873426437378, 'Type': 'ORGANI...
# 2852  [{'Score': 0.5693436861038208, 'Type': 'QUANTI...
# 2853  [{'Score': 0.8586263656616211, 'Type': 'LOCATI...
# 2854  [{'Score': 0.9894455671310425, 'Type': 'PERSON...
# 2855  [{'Score': 0.9876130223274231, 'Type': 'DATE',...
# 2856  [{'Score': 0.9590476751327515, 'Type': 'QUANTI...
# 2857  [{'Score': 0.398639053106308, 'Type': 'QUANTIT...
# 2858  [{'Score': 0.9981734752655029, 'Type': 'PERSON...
# 2859  [{'Score': 0.7720766067504883, 'Type': 'ORGANI...
# 2860  [{'Score': 0.7553373575210571, 'Type': 'ORGANI...
# 2861  [{'Score': 0.999053418636322, 'Type': 'PERSON'...
# 2862  [{'Score': 0.6757462620735168, 'Type': 'QUANTI...
# 2863  [{'Score': 0.7196873426437378, 'Type': 'ORGANI...
# 2864  [{'Score': 0.5693436861038208, 'Type': 'QUANTI...
# 2865  [{'Score': 0.8586263656616211, 'Type': 'LOCATI...
# 2866  [{'Score': 0.9894455671310425, 'Type': 'PERSON...
# 2867  [{'Score': 0.9876130223274231, 'Type': 'DATE',...
# 2868  [{'Score': 0.9590476751327515, 'Type': 'QUANTI...
# 2869  [{'Score': 0.398639053106308, 'Type': 'QUANTIT...
# 2870  [{'Score': 0.9981734752655029, 'Type': 'PERSON...
# 2871  [{'Score': 0.7720766067504883, 'Type': 'ORGANI...
# 2872  [{'Score': 0.7553373575210571, 'Type': 'ORGANI...
# 2873  [{'Score': 0.999053418636322, 'Type': 'PERSON'...
# 2874  [{'Score': 0.6757462620735168, 'Type': 'QUANTI...
# 2875  [{'Score': 0.7196873426437378, 'Type': 'ORGANI...
# 2876  [{'Score': 0.5693436861038208, 'Type': 'QUANTI...
# 2877  [{'Score': 0.8586263656616211, 'Type': 'LOCATI...
# 2878  [{'Score': 0.9894455671310425, 'Type': 'PERSON...
# 2879  [{'Score': 0.9876130223274231, 'Type': 'DATE',...
#
#                                              keyphrases sentiment  \
# 0     [{'Score': 0.9506336450576782, 'Text': 'Health...   NEUTRAL
# 1     [{'Score': 0.9670957922935486, 'Text': 'implem...   NEUTRAL
# 2     [{'Score': 0.7393423914909363, 'Text': 'Think ...   NEUTRAL
# 3     [{'Score': 0.9519321918487549, 'Text': 'Improv...   NEUTRAL
# 4     [{'Score': 0.9935138821601868, 'Text': 'the Su...   NEUTRAL
# 5     [{'Score': 0.4616624712944031, 'Text': 'Proces...   NEUTRAL
# 6     [{'Score': 0.9733020067214966, 'Text': 'a focu...   NEUTRAL
# 7     [{'Score': 0.9939494132995605, 'Text': 'tanks'...   NEUTRAL
# 8     [{'Score': 0.9855058789253235, 'Text': 'The gr...   NEUTRAL
# 9     [{'Score': 0.8619583249092102, 'Text': 'the po...   NEUTRAL
# 10    [{'Score': 0.986592710018158, 'Text': 'Experts...   NEUTRAL
# 11    [{'Score': 0.8420831561088562, 'Text': 'The Op...   NEUTRAL
# 12    [{'Score': 0.9506336450576782, 'Text': 'Health...   NEUTRAL
# 13    [{'Score': 0.9670957922935486, 'Text': 'implem...   NEUTRAL
# 14    [{'Score': 0.7393423914909363, 'Text': 'Think ...   NEUTRAL
# 15    [{'Score': 0.9519321918487549, 'Text': 'Improv...   NEUTRAL
# 16    [{'Score': 0.9935138821601868, 'Text': 'the Su...   NEUTRAL
# 17    [{'Score': 0.4616624712944031, 'Text': 'Proces...   NEUTRAL
# 18    [{'Score': 0.9733020067214966, 'Text': 'a focu...   NEUTRAL
# 19    [{'Score': 0.9939494132995605, 'Text': 'tanks'...   NEUTRAL
# 20    [{'Score': 0.9855058789253235, 'Text': 'The gr...   NEUTRAL
# 21    [{'Score': 0.8619583249092102, 'Text': 'the po...   NEUTRAL
# 22    [{'Score': 0.986592710018158, 'Text': 'Experts...   NEUTRAL
# 23    [{'Score': 0.8420831561088562, 'Text': 'The Op...   NEUTRAL
# 24    [{'Score': 0.9506336450576782, 'Text': 'Health...   NEUTRAL
# 25    [{'Score': 0.9670957922935486, 'Text': 'implem...   NEUTRAL
# 26    [{'Score': 0.7393423914909363, 'Text': 'Think ...   NEUTRAL
# 27    [{'Score': 0.9519321918487549, 'Text': 'Improv...   NEUTRAL
# 28    [{'Score': 0.9935138821601868, 'Text': 'the Su...   NEUTRAL
# 29    [{'Score': 0.4616624712944031, 'Text': 'Proces...   NEUTRAL
# ...                                                 ...       ...
# 2850  [{'Score': 0.8807178139686584, 'Text': 'Rating...   NEUTRAL
# 2851  [{'Score': 0.9683111310005188, 'Text': 'reflec...   NEUTRAL
# 2852  [{'Score': 0.9247344136238098, 'Text': 'Mobili...   NEUTRAL
# 2853  [{'Score': 0.7505537867546082, 'Text': 'think ...   NEUTRAL
# 2854  [{'Score': 0.9874573349952698, 'Text': 'your c...   NEUTRAL
# 2855  [{'Score': 0.8690492510795593, 'Text': 'Reflec...   NEUTRAL
# 2856  [{'Score': 0.9881378412246704, 'Text': 'Six th...   NEUTRAL
# 2857  [{'Score': 0.9922572374343872, 'Text': 'A new ...   NEUTRAL
# 2858  [{'Score': 0.9379271268844604, 'Text': 'The Id...   NEUTRAL
# 2859  [{'Score': 0.8468981385231018, 'Text': 'Kivu I...   NEUTRAL
# 2860  [{'Score': 0.9824256300926208, 'Text': 'the OT...   NEUTRAL
# 2861  [{'Score': 0.9973028898239136, 'Text': 'tanks'...   NEUTRAL
# 2862  [{'Score': 0.8807178139686584, 'Text': 'Rating...   NEUTRAL
# 2863  [{'Score': 0.9683111310005188, 'Text': 'reflec...   NEUTRAL
# 2864  [{'Score': 0.9247344136238098, 'Text': 'Mobili...   NEUTRAL
# 2865  [{'Score': 0.7505537867546082, 'Text': 'think ...   NEUTRAL
# 2866  [{'Score': 0.9874573349952698, 'Text': 'your c...   NEUTRAL
# 2867  [{'Score': 0.8690492510795593, 'Text': 'Reflec...   NEUTRAL
# 2868  [{'Score': 0.9881378412246704, 'Text': 'Six th...   NEUTRAL
# 2869  [{'Score': 0.9922572374343872, 'Text': 'A new ...   NEUTRAL
# 2870  [{'Score': 0.9379271268844604, 'Text': 'The Id...   NEUTRAL
# 2871  [{'Score': 0.8468981385231018, 'Text': 'Kivu I...   NEUTRAL
# 2872  [{'Score': 0.9824256300926208, 'Text': 'the OT...   NEUTRAL
# 2873  [{'Score': 0.9973028898239136, 'Text': 'tanks'...   NEUTRAL
# 2874  [{'Score': 0.8807178139686584, 'Text': 'Rating...   NEUTRAL
# 2875  [{'Score': 0.9683111310005188, 'Text': 'reflec...   NEUTRAL
# 2876  [{'Score': 0.9247344136238098, 'Text': 'Mobili...   NEUTRAL
# 2877  [{'Score': 0.7505537867546082, 'Text': 'think ...   NEUTRAL
# 2878  [{'Score': 0.9874573349952698, 'Text': 'your c...   NEUTRAL
# 2879  [{'Score': 0.8690492510795593, 'Text': 'Reflec...   NEUTRAL
#
#                                         sentiment_score
# 0     {'Positive': 0.0032495984341949224, 'Negative'...
# 1     {'Positive': 0.0028960187919437885, 'Negative'...
# 2     {'Positive': 0.01400300394743681, 'Negative': ...
# 3     {'Positive': 0.04854888841509819, 'Negative': ...
# 4     {'Positive': 0.0364609956741333, 'Negative': 0...
# 5     {'Positive': 0.01574675552546978, 'Negative': ...
# 6     {'Positive': 0.042726851999759674, 'Negative':...
# 7     {'Positive': 0.06777610629796982, 'Negative': ...
# 8     {'Positive': 0.30317506194114685, 'Negative': ...
# 9     {'Positive': 0.00322878360748291, 'Negative': ...
# 10    {'Positive': 0.0015325844287872314, 'Negative'...
# 11    {'Positive': 0.03398186340928078, 'Negative': ...
# 12    {'Positive': 0.0032495984341949224, 'Negative'...
# 13    {'Positive': 0.0028960187919437885, 'Negative'...
# 14    {'Positive': 0.01400300394743681, 'Negative': ...
# 15    {'Positive': 0.04854888841509819, 'Negative': ...
# 16    {'Positive': 0.0364609956741333, 'Negative': 0...
# 17    {'Positive': 0.01574675552546978, 'Negative': ...
# 18    {'Positive': 0.042726851999759674, 'Negative':...
# 19    {'Positive': 0.06777610629796982, 'Negative': ...
# 20    {'Positive': 0.30317506194114685, 'Negative': ...
# 21    {'Positive': 0.00322878360748291, 'Negative': ...
# 22    {'Positive': 0.0015325844287872314, 'Negative'...
# 23    {'Positive': 0.03398186340928078, 'Negative': ...
# 24    {'Positive': 0.0032495984341949224, 'Negative'...
# 25    {'Positive': 0.0028960187919437885, 'Negative'...
# 26    {'Positive': 0.01400300394743681, 'Negative': ...
# 27    {'Positive': 0.04854888841509819, 'Negative': ...
# 28    {'Positive': 0.0364609956741333, 'Negative': 0...
# 29    {'Positive': 0.01574675552546978, 'Negative': ...
# ...                                                 ...
# 2850  {'Positive': 0.039808109402656555, 'Negative':...
# 2851  {'Positive': 0.11700870096683502, 'Negative': ...
# 2852  {'Positive': 0.05896810069680214, 'Negative': ...
# 2853  {'Positive': 0.06784408539533615, 'Negative': ...
# 2854  {'Positive': 0.045732468366622925, 'Negative':...
# 2855  {'Positive': 0.024760307744145393, 'Negative':...
# 2856  {'Positive': 0.09104305505752563, 'Negative': ...
# 2857  {'Positive': 0.21026122570037842, 'Negative': ...
# 2858  {'Positive': 0.12761428952217102, 'Negative': ...
# 2859  {'Positive': 0.3048156499862671, 'Negative': 0...
# 2860  {'Positive': 0.35233592987060547, 'Negative': ...
# 2861  {'Positive': 0.031419187784194946, 'Negative':...
# 2862  {'Positive': 0.039808109402656555, 'Negative':...
# 2863  {'Positive': 0.11700870096683502, 'Negative': ...
# 2864  {'Positive': 0.05896810069680214, 'Negative': ...
# 2865  {'Positive': 0.06784408539533615, 'Negative': ...
# 2866  {'Positive': 0.045732468366622925, 'Negative':...
# 2867  {'Positive': 0.024760307744145393, 'Negative':...
# 2868  {'Positive': 0.09104305505752563, 'Negative': ...
# 2869  {'Positive': 0.21026122570037842, 'Negative': ...
# 2870  {'Positive': 0.12761428952217102, 'Negative': ...
# 2871  {'Positive': 0.3048156499862671, 'Negative': 0...
# 2872  {'Positive': 0.35233592987060547, 'Negative': ...
# 2873  {'Positive': 0.031419187784194946, 'Negative':...
# 2874  {'Positive': 0.039808109402656555, 'Negative':...
# 2875  {'Positive': 0.11700870096683502, 'Negative': ...
# 2876  {'Positive': 0.05896810069680214, 'Negative': ...
# 2877  {'Positive': 0.06784408539533615, 'Negative': ...
# 2878  {'Positive': 0.045732468366622925, 'Negative':...
# 2879  {'Positive': 0.024760307744145393, 'Negative':...
#
# [2879 rows x 8 columns]

# %%
articles_df.entities.values[0]
# Out:
# [{'Score': 0.9796985387802124,
#   'Type': 'LOCATION',
#   'Text': 'India',
#   'BeginOffset': 19,
#   'EndOffset': 24},
#  {'Score': 0.9825558662414551,
#   'Type': 'LOCATION',
#   'Text': 'India',
#   'BeginOffset': 474,
#   'EndOffset': 479},
#  {'Score': 0.8713580965995789,
#   'Type': 'ORGANIZATION',
#   'Text': 'National Institution for Transforming India NITI Aayog',
#   'BeginOffset': 604,
#   'EndOffset': 658},
#  {'Score': 0.9263405799865723,
#   'Type': 'LOCATION',
#   'Text': 'India',
#   'BeginOffset': 695,
#   'EndOffset': 700},
#  {'Score': 0.7133698463439941,
#   'Type': 'ORGANIZATION',
#   'Text': 'NITI Ayog',
#   'BeginOffset': 852,
#   'EndOffset': 861},
#  {'Score': 0.87736576795578,
#   'Type': 'LOCATION',
#   'Text': 'India',
#   'BeginOffset': 899,
#   'EndOffset': 904},
#  {'Score': 0.6385401487350464,
#   'Type': 'QUANTITY',
#   'Text': 'each SDG',
#   'BeginOffset': 949,
#   'EndOffset': 957},
#  {'Score': 0.9949374198913574,
#   'Type': 'DATE',
#   'Text': 'July',
#   'BeginOffset': 1954,
#   'EndOffset': 1958},
#  {'Score': 0.39655616879463196,
#   'Type': 'ORGANIZATION',
#   'Text': 'IIDS',
#   'BeginOffset': 1964,
#   'EndOffset': 1968},
#  {'Score': 0.5161482691764832,
#   'Type': 'ORGANIZATION',
#   'Text': 'PACS',
#   'BeginOffset': 1973,
#   'EndOffset': 1977},
#  {'Score': 0.5436816811561584,
#   'Type': 'LOCATION',
#   'Text': 'India',
#   'BeginOffset': 1978,
#   'EndOffset': 1983},
#  {'Score': 0.9270864129066467,
#   'Type': 'LOCATION',
#   'Text': 'India',
#   'BeginOffset': 2529,
#   'EndOffset': 2534},
#  {'Score': 0.7444614768028259,
#   'Type': 'ORGANIZATION',
#   'Text': 'MSPI',
#   'BeginOffset': 2540,
#   'EndOffset': 2544},
#  {'Score': 0.9732999801635742,
#   'Type': 'ORGANIZATION',
#   'Text': 'International Institute for Population Sciences',
#   'BeginOffset': 2930,
#   'EndOffset': 2977},
#  {'Score': 0.9976880550384521,
#   'Type': 'ORGANIZATION',
#   'Text': 'National Institute of Health and Family Welfare',
#   'BeginOffset': 2986,
#   'EndOffset': 3033},
#  {'Score': 0.9944875240325928,
#   'Type': 'ORGANIZATION',
#   'Text': 'National Institute of Health and Family Welfare and Population Research Centres',
#   'BeginOffset': 3297,
#   'EndOffset': 3376},
#  {'Score': 0.9743561148643494,
#   'Type': 'ORGANIZATION',
#   'Text': 'International Institute for Population Sciences Central Bureau of Health Information Anusandhan Trust and Centre for Equity for Health and Allied Themes \xa0CEHAT',
#   'BeginOffset': 3460,
#   'EndOffset': 3619},
#  {'Score': 0.7952966690063477,
#   'Type': 'LOCATION',
#   'Text': 'India',
#   'BeginOffset': 3867,
#   'EndOffset': 3872}]

# %%
# articles_df.apply(extract_node, axis=1)

# %%
import pickle
with open('ent_sent_keyphrase.pickle', 'rb') as handle:
    articles_df = pickle.load(handle)
